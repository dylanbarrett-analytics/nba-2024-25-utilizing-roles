# %% [markdown]
# # NBA 2024-25: Utilizing Roles
# ## Notebook 01: Data Acquisition
# This notebook collects game-level player statistics for the 2024-25 NBA regular season using the NBA API. It combines all player game logs into a single DataFrame.

# %%
# Install NBA API
# !pip install nba_api
# Out:
# Requirement already satisfied: nba_api in c:\users\dylan\anaconda3\lib\site-packages (1.11.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dylan\anaconda3\lib\site-packages (from nba_api) (1.26.4)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\dylan\anaconda3\lib\site-packages (from nba_api) (2.2.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\dylan\anaconda3\lib\site-packages (from nba_api) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dylan\anaconda3\lib\site-packages (from pandas>=2.2.0->nba_api) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dylan\anaconda3\lib\site-packages (from pandas>=2.2.0->nba_api) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dylan\anaconda3\lib\site-packages (from pandas>=2.2.0->nba_api) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dylan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dylan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dylan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dylan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2025.6.15)
# Requirement already satisfied: six>=1.5 in c:\users\dylan\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nba_api) (1.16.0)

# %%
# Import libraries
import pandas as pd
import time
from tqdm import tqdm
from nba_api.stats.endpoints import PlayerGameLog, leaguedashplayerstats
from nba_api.stats.static import players

# %% [markdown]
# ___
# ## Acquiring Game-Level Player Statistics

# %%
# Get all players who registered a statistic during 2024-25 regular season
player_stats = leaguedashplayerstats.LeagueDashPlayerStats(
    season="2024-25",
    season_type_all_star="Regular Season"
).get_data_frames()[0]

print(f"{len(player_stats)} players")
# Out:
# 569 players

# %%
# Player IDs of these 569 players
player_ids = player_stats["PLAYER_ID"].unique().tolist()

# %%
# --- Download each player's game log ---

all_game_logs = []

for pid in tqdm(player_ids, desc="Downloading player game logs"):
    try:
        game_logs = PlayerGameLog(player_id=str(pid), season="2024-25").get_data_frames()[0]
        game_logs["PLAYER_ID"] = pid
        all_game_logs.append(game_logs)
        time.sleep(0.6)
    except Exception as e:
        print(f"Failed: {pid}", e)
# Out:
# Downloading player game logs: 100%|██████████| 569/569 [07:10<00:00,  1.32it/s]

# %%
# Combine into one DataFrame
player_game_logs_2024_25 = pd.concat(all_game_logs, ignore_index=True)
player_game_logs_2024_25.head(5)
# Out:
#   SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0     22024    1630639  0022401197  Apr 13, 2025    TOR @ SAS  L   21    3
# 1     22024    1630639  0022401178  Apr 11, 2025    TOR @ DAL  L   32    3
# 2     22024    1630639  0022401158  Apr 09, 2025  TOR vs. CHA  W   28    5
# 3     22024    1630639  0022401134  Apr 06, 2025    TOR @ BKN  W   22    5
# 4     22024    1630639  0022401121  Apr 04, 2025  TOR vs. DET  L   23    2
#
#    FGA  FG_PCT  ...  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0    7   0.429  ...    0    0    0    0    1   1   14          -5
# 1   10   0.300  ...   10    2    1    0    0   3   12         -10
# 2    9   0.556  ...    6    7    1    0    0   1   14          18
# 3    9   0.556  ...    1    0    2    0    2   2   13          -6
# 4    7   0.286  ...    3    1    1    2    1   2    9          -2
#
#    VIDEO_AVAILABLE  PLAYER_ID
# 0                1    1630639
# 1                1    1630639
# 2                1    1630639
# 3                1    1630639
# 4                1    1630639
#
# [5 rows x 28 columns]

# %%
# Drop duplicate Player_ID column
player_game_logs_2024_25 = player_game_logs_2024_25.drop(columns=["PLAYER_ID"])

# %%
# Confirm columns
player_game_logs_2024_25.columns
# Out:
# Index(['SEASON_ID', 'Player_ID', 'Game_ID', 'GAME_DATE', 'MATCHUP', 'WL',
#        'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
#        'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'PLUS_MINUS', 'VIDEO_AVAILABLE'],
#       dtype='object')

# %% [markdown]
# > Player IDs are present, but player names are missing.

# %% [markdown]
# ___
# ## Get Player Names

# %%
# Get player directory
players = pd.DataFrame(players.get_players())
players.head(5)
# Out:
#       id            full_name first_name     last_name  is_active
# 0  76001       Alaa Abdelnaby       Alaa     Abdelnaby      False
# 1  76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz      False
# 2  76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar      False
# 3     51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf      False
# 4   1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad      False

# %%
# Rename columns to match player logs column names
players = players.rename(columns={
    "id": "Player_ID",
    "full_name": "Player_Name"
})

# %%
# Merge player names with player game logs
player_game_logs_2024_25 = player_game_logs_2024_25.merge(
    players[["Player_ID", "Player_Name"]],
    on="Player_ID",
    how="left"
)

# %%
# Reorder columns so that `PLAYER_NAME` column is first
cols = ["Player_Name"] + [c for c in player_game_logs_2024_25.columns if c != "Player_Name"]
player_game_logs_2024_25 = player_game_logs_2024_25[cols]

# %%
# Inspect structure
player_game_logs_2024_25.head(5)
# Out:
#    Player_Name SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  \
# 0  A.J. Lawson     22024    1630639  0022401197  Apr 13, 2025    TOR @ SAS  L
# 1  A.J. Lawson     22024    1630639  0022401178  Apr 11, 2025    TOR @ DAL  L
# 2  A.J. Lawson     22024    1630639  0022401158  Apr 09, 2025  TOR vs. CHA  W
# 3  A.J. Lawson     22024    1630639  0022401134  Apr 06, 2025    TOR @ BKN  W
# 4  A.J. Lawson     22024    1630639  0022401121  Apr 04, 2025  TOR vs. DET  L
#
#    MIN  FGM  FGA  ...  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0   21    3    7  ...     0    0    0    0    0    1   1   14          -5
# 1   32    3   10  ...     8   10    2    1    0    0   3   12         -10
# 2   28    5    9  ...     4    6    7    1    0    0   1   14          18
# 3   22    5    9  ...     1    1    0    2    0    2   2   13          -6
# 4   23    2    7  ...     2    3    1    1    2    1   2    9          -2
#
#    VIDEO_AVAILABLE
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
#
# [5 rows x 28 columns]

# %%
# Quick sanity checks
print(f"Number of rows: {len(player_game_logs_2024_25):,}")
print(f"Unique players: {player_game_logs_2024_25["Player_ID"].nunique()}")
# Out:
# Number of rows: 26,306
# Unique players: 569

# %%
# Drop nonessential columns
player_game_logs_2024_25 = player_game_logs_2024_25.drop(columns=["VIDEO_AVAILABLE"])

# %%
# Confirm updated columns
player_game_logs_2024_25.columns
# Out:
# Index(['Player_Name', 'SEASON_ID', 'Player_ID', 'Game_ID', 'GAME_DATE',
#        'MATCHUP', 'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS', 'PLUS_MINUS'],
#       dtype='object')

# %% [markdown]
# ___
# ## Save

# %%
# Save to Parquet
player_game_logs_2024_25.to_parquet("NBA_Player_GameLogs_2024_25.parquet")
